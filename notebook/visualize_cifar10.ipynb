# %%
import numpy as np
import matplotlib.pyplot as plt
import chainer
# Out:
# /Users/ootaryuunosuke/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# #### cifar10のクラスラベル
# - 0: airplane (飛行機)
# - 1: automobile (自動車)
# - 2: bird (鳥)
# - 3: cat (猫)
# - 4: deer (鹿)
# - 5: dog (犬)
# - 6: frog (カエル)
# - 7: horse (馬)
# - 8: ship (船)
# - 9: truck (トラック)

# %%
(train, test) = chainer.datasets.get_cifar10()
print("訓練データ数: ", len(train))
print("テストデータ数: ", len(test))
# Out:
# 訓練データ数:  50000
# テストデータ数:  10000

# %%
# 複数画像の表示
fig,ax = plt.subplots(nrows=3,ncols=5,sharex=True,sharey=True,figsize=(18,10))
ax = ax.flatten()
for i in range(15):
    img = np.dstack((train[i][0][0],train[i][0][1],train[i][0][2]))
    ax[i].imshow(img,interpolation='none')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.show()

# %%
# 1枚画像の表示
plt.figure(figsize=(4,4))
img = np.dstack((train[0][0][0], train[0][0][1], train[0][0][2]))
plt.imshow(img)
plt.show()

# %%
# 特定クラスラベルの画像を表示
def display_specific_img(class_label):
    specific_img = get_specific_img(class_label)
    fig,ax = plt.subplots(nrows=3,ncols=5,sharex=True,sharey=True,figsize=(18,10))
    ax = ax.flatten()
    for i in range(15):
        img = specific_img[i][0]
        img = np.dstack((img[0], img[1], img[2]))
        ax[i].imshow(img,interpolation='none')

    ax[0].set_xticks([])
    ax[0].set_yticks([])
    plt.tight_layout()
    plt.show()

# 特定クラスラベル画像の取得
def get_specific_img(class_label):
    specific_img = []
    for data in train:
        label = data[1]
        if label == class_label:
            specific_img.append(data)
    return specific_img

# %%
display_specific_img(class_label=0) # 飛行機

# %%
display_specific_img(class_label=1) # 車

# %%
display_specific_img(class_label=2) # 鳥

# %%
display_specific_img(class_label=3) # 猫

# %%
display_specific_img(class_label=4) # 鹿

# %%
display_specific_img(class_label=5) # 犬

# %%
display_specific_img(class_label=6) # カエル

# %%
display_specific_img(class_label=7) # 馬

# %%
display_specific_img(class_label=8) # 船

# %%
display_specific_img(class_label=9) # トラック
