# %% [markdown]
# # eval1 -------------------------------------------
# ## v1-v8
#
# ### 従来方法で全体のデータ数を1800ずつ増加させた場合の精度の推移
# - 3クラス分類: Cifar10[1,2,8]
# - 全初期訓練データ数: 1800
# - 各反復の全データ数: [1800, 3600, 5400, 7200, 9000, 10800, 12600, 14400]
#
# ## v9-v16
#
# ### 従来方法で全体のデータ数を900ずつ増加させた場合の精度の推移
# - 3クラス分類
# - 全初期訓練データ数: 900
# - 各反復の全データ数: [900, 1800, 2700, 3600, 4500, 5400, 6300, 7200]

# %% [markdown]
# # eval2 -------------------------------------------
# ## v1-v8
#
# ### 従来方法で全体のデータ数を300ずつ増加させた誤差収束速度の比較
# - 3クラス分類: Cifar10[1,2,8]
# - 全初期訓練データ数: 300
# - 各反復の全データ数: [300, 600, 900, 1200, 1500, 1800, 2100, 2400]
# - eval_lossの設定値:
#  - a=50
#  - n=10

# %% [markdown]
# # eval3 -------------------------------------------
# ## v1-v10, extra_v10
#
# ### 従来方法で全く同じデータを追加学習した場合と一括で学習した場合の比較
# - 3クラス分類: Cifar10[1,2,8]
# - 追加学習:
#  - 全初期訓練データ数: 600
#  - 各反復の全データ数: [600, 1200, 1800, 2400, 3000, 3600, 4200, 4800, 5400, 6000]
# - 一括学習:
#  - 全初期訓練データ数: 6000
#  - 各反復の全データ数: [6000]

# %% [markdown]
# # eval4 -------------------------------------------
# ## v1-v20
#
# ### 1回目: 従来方法で20反復(再学習)
# - 3クラス分類: Cifar10[1,2,8]
# - 初期訓練データ: 120
# - 追加訓練データ: 120
# - 初期テストデータ: 30
# - 追加テストデータ: 30
# - 各反復の全データ数: [120, 240, 360, 480, 600, 720, 840, 960, 1080, 1200, 1320, 1440, 1560, 1680, 1800, 1920, 2040, 2160, 2280, 2400]
# - eval_lossの設定値:
#  - a=50
#  - n=20

# %% [markdown]
# # eval5 -------------------------------------------
# ## v1-v20
#
# ### 2回目: 従来方法で20反復(再学習)
# - 3クラス分類: Cifar10[1,2,8]
# - 初期訓練データ: 120
# - 追加訓練データ: 120
# - 初期テストデータ: 30
# - 追加テストデータ: 30
# - 各反復の全データ数: [120, 240, 360, 480, 600, 720, 840, 960, 1080, 1200, 1320, 1440, 1560, 1680, 1800, 1920, 2040, 2160, 2280, 2400]
# - eval_lossの設定値:
#  - a=50
#  - n=20

# %% [markdown]
# # eval6 -------------------------------------------
# ## v1-v20
#
# ### 3回目: 従来方法で20反復(再学習)
# - 3クラス分類: Cifar10[1,2,8]
# - 初期訓練データ: 120
# - 追加訓練データ: 120
# - 初期テストデータ: 30
# - 追加テストデータ: 30
# - 各反復の全データ数: [120, 240, 360, 480, 600, 720, 840, 960, 1080, 1200, 1320, 1440, 1560, 1680, 1800, 1920, 2040, 2160, 2280, 2400]
# - eval_lossの設定値:
#  - a=50
#  - n=20

# %% [markdown]
# # eval7-------------------------------------------
# ## v1-v20
#
# ### 4回目: 従来方法で20反復(再学習)
# - 3クラス分類: Cifar10[1,2,8]
# - 初期訓練データ: 120
# - 追加訓練データ: 120
# - 初期テストデータ: 30
# - 追加テストデータ: 30
# - 各反復の全データ数: [120, 240, 360, 480, 600, 720, 840, 960, 1080, 1200, 1320, 1440, 1560, 1680, 1800, 1920, 2040, 2160, 2280, 2400]
# - eval_lossの設定値:
#  - a=50
#  - n=20

# %% [markdown]
# # eval8-------------------------------------------
# ## v1-v20
#
# ### 5回目: 従来方法で20反復(再学習)
# - 3クラス分類: Cifar10[1,2,8]
# - 初期訓練データ: 120
# - 追加訓練データ: 120
# - 初期テストデータ: 30
# - 追加テストデータ: 30
# - 各反復の全データ数: [120, 240, 360, 480, 600, 720, 840, 960, 1080, 1200, 1320, 1440, 1560, 1680, 1800, 1920, 2040, 2160, 2280, 2400]
# - eval_lossの設定値:
#  - a=50
#  - n=20
