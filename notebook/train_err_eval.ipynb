# %% [markdown]
# ## ・訓練誤差収束速度の計測

# %%
import json
import matplotlib.pyplot as plt

# %%
def load_json(json_path):
    f = open(json_path, "r")
    loaded_json = json.load(f)
    return loaded_json

def get_train_losses(train_log):
    train_losses = []
    for i in train_log:
        train_losses.append(i["train loss"])
    return train_losses

def plot_train_losses(train_losses, color="black"):
    x = list(range(1, len(train_losses)+1))
    y = train_losses
    plt.figure(figsize=(8,6))
    plt.plot(x, y, color=color, linewidth=2)

# %%
# 訓練誤差収束速度の評価
# a: 係数
# n: 誤差の傾きの計測範囲
# Ep: pエポックにおける訓練誤差
# 訓練誤差収束速度: S = Σ-a/k(Enk - Enk-n+1)
# Out:
# '\na: 係数\nn: 誤差の傾きの計測範囲\nEp: pエポックにおける訓練誤差\n'

# %%
json_path = "../prototype/pytorch_prototype/result/v5/log.json"
train_log = load_json(json_path)
train_losses = get_train_losses(train_log)
plot_train_losses(train_losses, color="green")

# %%
json_path = "../prototype/pytorch_prototype/result/v6/log.json"
train_log = load_json(json_path)
train_losses = get_train_losses(train_log)
plot_train_losses(train_losses, color="blue")

# %%
# Out:
# [{'epoch': 1,
#   'learning rate': 0.001,
#   'test accuracy': 0.3333333333333333,
#   'test loss': 1.1216507822672526,
#   'train accuracy': 0.3333333333333333,
#   'train loss': 1.1068223429361979},
#  {'epoch': 2,
#   'learning rate': 0.001,
#   'test accuracy': 0.33466666666666667,
#   'test loss': 1.117557601928711,
#   'train accuracy': 0.3334,
#   'train loss': 1.102372358194987},
#  {'epoch': 3,
#   'learning rate': 0.001,
#   'test accuracy': 0.49033333333333334,
#   'test loss': 1.1109625905354819,
#   'train accuracy': 0.3781333333333333,
#   'train loss': 1.0966899485270183},
#  {'epoch': 4,
#   'learning rate': 0.001,
#   'test accuracy': 0.5593333333333333,
#   'test loss': 1.0967500966389974,
#   'train accuracy': 0.561,
#   'train loss': 1.086901284790039},
#  {'epoch': 5,
#   'learning rate': 0.001,
#   'test accuracy': 0.5646666666666667,
#   'test loss': 1.0570432332356772,
#   'train accuracy': 0.5738666666666666,
#   'train loss': 1.0628621805826823},
#  {'epoch': 6,
#   'learning rate': 0.001,
#   'test accuracy': 0.582,
#   'test loss': 0.9765096588134765,
#   'train accuracy': 0.5746,
#   'train loss': 1.0034273880004883},
#  {'epoch': 7,
#   'learning rate': 0.001,
#   'test accuracy': 0.6033333333333334,
#   'test loss': 0.9114523137410482,
#   'train accuracy': 0.5924666666666667,
#   'train loss': 0.928063594563802},
#  {'epoch': 8,
#   'learning rate': 0.001,
#   'test accuracy': 0.6303333333333333,
#   'test loss': 0.8596357421875,
#   'train accuracy': 0.6198,
#   'train loss': 0.8709674168904622},
#  {'epoch': 9,
#   'learning rate': 0.001,
#   'test accuracy': 0.6583333333333333,
#   'test loss': 0.8079059270222981,
#   'train accuracy': 0.6517333333333334,
#   'train loss': 0.8154315755208333},
#  {'epoch': 10,
#   'learning rate': 0.001,
#   'test accuracy': 0.6746666666666666,
#   'test loss': 0.7557725677490235,
#   'train accuracy': 0.6796666666666666,
#   'train loss': 0.7646643427530925},
#  {'epoch': 11,
#   'learning rate': 0.001,
#   'test accuracy': 0.717,
#   'test loss': 0.684210210164388,
#   'train accuracy': 0.7132666666666667,
#   'train loss': 0.7040116561889649},
#  {'epoch': 12,
#   'learning rate': 0.001,
#   'test accuracy': 0.736,
#   'test loss': 0.6413501561482747,
#   'train accuracy': 0.7434666666666667,
#   'train loss': 0.6470094510396321},
#  {'epoch': 13,
#   'learning rate': 0.001,
#   'test accuracy': 0.76,
#   'test loss': 0.5959882901509603,
#   'train accuracy': 0.7624,
#   'train loss': 0.5981385981241862},
#  {'epoch': 14,
#   'learning rate': 0.001,
#   'test accuracy': 0.7733333333333333,
#   'test loss': 0.5555276527404786,
#   'train accuracy': 0.7769333333333334,
#   'train loss': 0.5643209335327148},
#  {'epoch': 15,
#   'learning rate': 0.001,
#   'test accuracy': 0.783,
#   'test loss': 0.5311188189188639,
#   'train accuracy': 0.7871333333333334,
#   'train loss': 0.5375335599263509},
#  {'epoch': 16,
#   'learning rate': 0.001,
#   'test accuracy': 0.7766666666666666,
#   'test loss': 0.5421175429026286,
#   'train accuracy': 0.7996666666666666,
#   'train loss': 0.5136471031188965},
#  {'epoch': 17,
#   'learning rate': 0.001,
#   'test accuracy': 0.7963333333333333,
#   'test loss': 0.49773983510335285,
#   'train accuracy': 0.8046666666666666,
#   'train loss': 0.49767011998494465},
#  {'epoch': 18,
#   'learning rate': 0.001,
#   'test accuracy': 0.81,
#   'test loss': 0.4825559450785319,
#   'train accuracy': 0.8147333333333333,
#   'train loss': 0.4806153607686361},
#  {'epoch': 19,
#   'learning rate': 0.001,
#   'test accuracy': 0.816,
#   'test loss': 0.47006974029541015,
#   'train accuracy': 0.8209333333333333,
#   'train loss': 0.4632838333129883},
#  {'epoch': 20,
#   'learning rate': 0.001,
#   'test accuracy': 0.823,
#   'test loss': 0.456698584874471,
#   'train accuracy': 0.8265333333333333,
#   'train loss': 0.4518013231913249},
#  {'epoch': 21,
#   'learning rate': 0.001,
#   'test accuracy': 0.8266666666666667,
#   'test loss': 0.4545099805196126,
#   'train accuracy': 0.8306,
#   'train loss': 0.44161444829305013},
#  {'epoch': 22,
#   'learning rate': 0.001,
#   'test accuracy': 0.8306666666666667,
#   'test loss': 0.43985619735717774,
#   'train accuracy': 0.8358666666666666,
#   'train loss': 0.42997902272542315},
#  {'epoch': 23,
#   'learning rate': 0.001,
#   'test accuracy': 0.8306666666666667,
#   'test loss': 0.4333136774698893,
#   'train accuracy': 0.84,
#   'train loss': 0.4208899449666341},
#  {'epoch': 24,
#   'learning rate': 0.001,
#   'test accuracy': 0.8416666666666667,
#   'test loss': 0.4203767223358154,
#   'train accuracy': 0.8444,
#   'train loss': 0.4079806032816569},
#  {'epoch': 25,
#   'learning rate': 0.001,
#   'test accuracy': 0.8313333333333334,
#   'test loss': 0.41831442387898765,
#   'train accuracy': 0.8477333333333333,
#   'train loss': 0.399787806447347},
#  {'epoch': 26,
#   'learning rate': 0.001,
#   'test accuracy': 0.8316666666666667,
#   'test loss': 0.4433885726928711,
#   'train accuracy': 0.855,
#   'train loss': 0.38808841501871744},
#  {'epoch': 27,
#   'learning rate': 0.001,
#   'test accuracy': 0.848,
#   'test loss': 0.40037081464131674,
#   'train accuracy': 0.8531333333333333,
#   'train loss': 0.383239576848348},
#  {'epoch': 28,
#   'learning rate': 0.001,
#   'test accuracy': 0.85,
#   'test loss': 0.38997181447347007,
#   'train accuracy': 0.8596666666666667,
#   'train loss': 0.37345380160013836},
#  {'epoch': 29,
#   'learning rate': 0.001,
#   'test accuracy': 0.853,
#   'test loss': 0.3882805995941162,
#   'train accuracy': 0.8613333333333333,
#   'train loss': 0.3672950304667155},
#  {'epoch': 30,
#   'learning rate': 0.001,
#   'test accuracy': 0.8496666666666667,
#   'test loss': 0.3946594079335531,
#   'train accuracy': 0.8632666666666666,
#   'train loss': 0.3641446590423584},
#  {'epoch': 31,
#   'learning rate': 0.001,
#   'test accuracy': 0.86,
#   'test loss': 0.37523049354553223,
#   'train accuracy': 0.8650666666666667,
#   'train loss': 0.3561907379150391},
#  {'epoch': 32,
#   'learning rate': 0.001,
#   'test accuracy': 0.8506666666666667,
#   'test loss': 0.3722492421468099,
#   'train accuracy': 0.8682,
#   'train loss': 0.34663710009257},
#  {'epoch': 33,
#   'learning rate': 0.001,
#   'test accuracy': 0.8533333333333334,
#   'test loss': 0.36579616991678876,
#   'train accuracy': 0.8703333333333333,
#   'train loss': 0.33910202560424807},
#  {'epoch': 34,
#   'learning rate': 0.001,
#   'test accuracy': 0.86,
#   'test loss': 0.36426763598124184,
#   'train accuracy': 0.8702,
#   'train loss': 0.3387756341934204},
#  {'epoch': 35,
#   'learning rate': 0.001,
#   'test accuracy': 0.8516666666666667,
#   'test loss': 0.3773721726735433,
#   'train accuracy': 0.8740666666666667,
#   'train loss': 0.3301130238850912},
#  {'epoch': 36,
#   'learning rate': 0.001,
#   'test accuracy': 0.8636666666666667,
#   'test loss': 0.3573159294128418,
#   'train accuracy': 0.8761333333333333,
#   'train loss': 0.3277570260365804},
#  {'epoch': 37,
#   'learning rate': 0.001,
#   'test accuracy': 0.8653333333333333,
#   'test loss': 0.3459815591176351,
#   'train accuracy': 0.8802,
#   'train loss': 0.3246970656077067},
#  {'epoch': 38,
#   'learning rate': 0.001,
#   'test accuracy': 0.868,
#   'test loss': 0.34191736284891766,
#   'train accuracy': 0.8818,
#   'train loss': 0.3183758042653402},
#  {'epoch': 39,
#   'learning rate': 0.001,
#   'test accuracy': 0.8633333333333333,
#   'test loss': 0.3704259071350098,
#   'train accuracy': 0.8820666666666667,
#   'train loss': 0.3180524454752604},
#  {'epoch': 40,
#   'learning rate': 0.001,
#   'test accuracy': 0.868,
#   'test loss': 0.341214906056722,
#   'train accuracy': 0.881,
#   'train loss': 0.3152110277811686},
#  {'epoch': 41,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.876,
#   'test loss': 0.33042622756958007,
#   'train accuracy': 0.8904,
#   'train loss': 0.29617702140808105},
#  {'epoch': 42,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8733333333333333,
#   'test loss': 0.32833398501078287,
#   'train accuracy': 0.8905333333333333,
#   'train loss': 0.2936779167175293},
#  {'epoch': 43,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8753333333333333,
#   'test loss': 0.32753779538472494,
#   'train accuracy': 0.8910666666666667,
#   'train loss': 0.29362477747599286},
#  {'epoch': 44,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.878,
#   'test loss': 0.3277533156077067,
#   'train accuracy': 0.8916666666666667,
#   'train loss': 0.2926982799530029},
#  {'epoch': 45,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8766666666666667,
#   'test loss': 0.3280625928243001,
#   'train accuracy': 0.8929333333333334,
#   'train loss': 0.29162866439819335},
#  {'epoch': 46,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8736666666666667,
#   'test loss': 0.3266104367574056,
#   'train accuracy': 0.8910666666666667,
#   'train loss': 0.29102954762776695},
#  {'epoch': 47,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.877,
#   'test loss': 0.3289983253479004,
#   'train accuracy': 0.8918666666666667,
#   'train loss': 0.2921078517913818},
#  {'epoch': 48,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8766666666666667,
#   'test loss': 0.325498384475708,
#   'train accuracy': 0.8926666666666667,
#   'train loss': 0.2885860973993937},
#  {'epoch': 49,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8773333333333333,
#   'test loss': 0.32514905103047687,
#   'train accuracy': 0.8919333333333334,
#   'train loss': 0.2894963680267334},
#  {'epoch': 50,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8753333333333333,
#   'test loss': 0.3252811107635498,
#   'train accuracy': 0.8934666666666666,
#   'train loss': 0.2875580197016398},
#  {'epoch': 51,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.878,
#   'test loss': 0.32453659756978354,
#   'train accuracy': 0.8923333333333333,
#   'train loss': 0.28945464731852216},
#  {'epoch': 52,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8773333333333333,
#   'test loss': 0.325924648920695,
#   'train accuracy': 0.8928,
#   'train loss': 0.2877985471089681},
#  {'epoch': 53,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.875,
#   'test loss': 0.32447352663675944,
#   'train accuracy': 0.8934666666666666,
#   'train loss': 0.28892648696899415},
#  {'epoch': 54,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.876,
#   'test loss': 0.32561498006184897,
#   'train accuracy': 0.8943333333333333,
#   'train loss': 0.28900561192830404},
#  {'epoch': 55,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8766666666666667,
#   'test loss': 0.3248379809061686,
#   'train accuracy': 0.8942,
#   'train loss': 0.2867557352701823},
#  {'epoch': 56,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.879,
#   'test loss': 0.3243568846384684,
#   'train accuracy': 0.8941333333333333,
#   'train loss': 0.28569983253479003},
#  {'epoch': 57,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8746666666666667,
#   'test loss': 0.32351922607421874,
#   'train accuracy': 0.8946666666666667,
#   'train loss': 0.28657607345581054},
#  {'epoch': 58,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.32374910163879395,
#   'train accuracy': 0.8949333333333334,
#   'train loss': 0.2847558163960775},
#  {'epoch': 59,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.878,
#   'test loss': 0.32188416544596354,
#   'train accuracy': 0.8959333333333334,
#   'train loss': 0.2878531279246012},
#  {'epoch': 60,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8766666666666667,
#   'test loss': 0.32206248919169106,
#   'train accuracy': 0.8934666666666666,
#   'train loss': 0.28482429733276365},
#  {'epoch': 61,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.876,
#   'test loss': 0.3227258332570394,
#   'train accuracy': 0.8948,
#   'train loss': 0.28201453253428144},
#  {'epoch': 62,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.879,
#   'test loss': 0.32229589589436847,
#   'train accuracy': 0.8950666666666667,
#   'train loss': 0.28304257202148436},
#  {'epoch': 63,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.875,
#   'test loss': 0.3220454635620117,
#   'train accuracy': 0.8961333333333333,
#   'train loss': 0.2824197132110596},
#  {'epoch': 64,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.3227229976654053,
#   'train accuracy': 0.8944666666666666,
#   'train loss': 0.28306350288391113},
#  {'epoch': 65,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.875,
#   'test loss': 0.32396686935424807,
#   'train accuracy': 0.896,
#   'train loss': 0.2810354414621989},
#  {'epoch': 66,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.876,
#   'test loss': 0.32153672790527343,
#   'train accuracy': 0.895,
#   'train loss': 0.2826504461924235},
#  {'epoch': 67,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8786666666666667,
#   'test loss': 0.32010140546162924,
#   'train accuracy': 0.8962666666666667,
#   'train loss': 0.280522364171346},
#  {'epoch': 68,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8773333333333333,
#   'test loss': 0.32207433446248374,
#   'train accuracy': 0.8965333333333333,
#   'train loss': 0.28237382723490395},
#  {'epoch': 69,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.876,
#   'test loss': 0.320260399500529,
#   'train accuracy': 0.8959333333333334,
#   'train loss': 0.2802091094970703},
#  {'epoch': 70,
#   'learning rate': 0.00010000000000000002,
#   'test accuracy': 0.8803333333333333,
#   'test loss': 0.3191000105539958,
#   'train accuracy': 0.8966,
#   'train loss': 0.2791328946431478},
#  {'epoch': 71,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.878,
#   'test loss': 0.31911117998758953,
#   'train accuracy': 0.8972666666666667,
#   'train loss': 0.27854351654052734},
#  {'epoch': 72,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.3193321164449056,
#   'train accuracy': 0.8974666666666666,
#   'train loss': 0.27778611068725584},
#  {'epoch': 73,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.878,
#   'test loss': 0.31890019416809084,
#   'train accuracy': 0.8971333333333333,
#   'train loss': 0.2780486101786296},
#  {'epoch': 74,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8776666666666667,
#   'test loss': 0.3190606555938721,
#   'train accuracy': 0.8974666666666666,
#   'train loss': 0.27968655687967936},
#  {'epoch': 75,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8776666666666667,
#   'test loss': 0.31897515869140625,
#   'train accuracy': 0.8971333333333333,
#   'train loss': 0.2797854455312093},
#  {'epoch': 76,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8776666666666667,
#   'test loss': 0.3188543192545573,
#   'train accuracy': 0.8972666666666667,
#   'train loss': 0.27811107228597004},
#  {'epoch': 77,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.879,
#   'test loss': 0.31899076080322264,
#   'train accuracy': 0.8976,
#   'train loss': 0.2767999749501546},
#  {'epoch': 78,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8786666666666667,
#   'test loss': 0.31883776410420733,
#   'train accuracy': 0.8976,
#   'train loss': 0.27759184239705403},
#  {'epoch': 79,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.3187164510091146,
#   'train accuracy': 0.8971333333333333,
#   'train loss': 0.27823872973124186},
#  {'epoch': 80,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8773333333333333,
#   'test loss': 0.31886734580993653,
#   'train accuracy': 0.8977333333333334,
#   'train loss': 0.2761971284548442},
#  {'epoch': 81,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.877,
#   'test loss': 0.3188116232554118,
#   'train accuracy': 0.8978,
#   'train loss': 0.277179371770223},
#  {'epoch': 82,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8786666666666667,
#   'test loss': 0.3189907169342041,
#   'train accuracy': 0.8980666666666667,
#   'train loss': 0.27845809364318846},
#  {'epoch': 83,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.3186579647064209,
#   'train accuracy': 0.8976,
#   'train loss': 0.2768363343556722},
#  {'epoch': 84,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8786666666666667,
#   'test loss': 0.3189128239949544,
#   'train accuracy': 0.8975333333333333,
#   'train loss': 0.2772891263326009},
#  {'epoch': 85,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.3187146816253662,
#   'train accuracy': 0.898,
#   'train loss': 0.2773550506591797},
#  {'epoch': 86,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.31855571683247885,
#   'train accuracy': 0.8974666666666666,
#   'train loss': 0.2770895837148031},
#  {'epoch': 87,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8763333333333333,
#   'test loss': 0.3186934102376302,
#   'train accuracy': 0.8978666666666667,
#   'train loss': 0.2768008209228516},
#  {'epoch': 88,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8786666666666667,
#   'test loss': 0.3187889684041341,
#   'train accuracy': 0.8977333333333334,
#   'train loss': 0.27625446275075277},
#  {'epoch': 89,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.3187046553293864,
#   'train accuracy': 0.898,
#   'train loss': 0.2772012500762939},
#  {'epoch': 90,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.3185458170572917,
#   'train accuracy': 0.8974,
#   'train loss': 0.2774137274424235},
#  {'epoch': 91,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.31833979606628415,
#   'train accuracy': 0.8974666666666666,
#   'train loss': 0.2775745422363281},
#  {'epoch': 92,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8793333333333333,
#   'test loss': 0.3183377850850423,
#   'train accuracy': 0.8982666666666667,
#   'train loss': 0.27646933619181313},
#  {'epoch': 93,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.878,
#   'test loss': 0.3185915781656901,
#   'train accuracy': 0.8974,
#   'train loss': 0.2764801951090495},
#  {'epoch': 94,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8786666666666667,
#   'test loss': 0.3183975156148275,
#   'train accuracy': 0.8979333333333334,
#   'train loss': 0.27644728202819824},
#  {'epoch': 95,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.3183559792836507,
#   'train accuracy': 0.8975333333333333,
#   'train loss': 0.27658645502726237},
#  {'epoch': 96,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.879,
#   'test loss': 0.31848238563537595,
#   'train accuracy': 0.8982666666666667,
#   'train loss': 0.2766825401306152},
#  {'epoch': 97,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.31825698661804197,
#   'train accuracy': 0.8978,
#   'train loss': 0.2786876881917318},
#  {'epoch': 98,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8786666666666667,
#   'test loss': 0.3184436124165853,
#   'train accuracy': 0.8978666666666667,
#   'train loss': 0.2778239870707194},
#  {'epoch': 99,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.8783333333333333,
#   'test loss': 0.3182351271311442,
#   'train accuracy': 0.8976666666666666,
#   'train loss': 0.2768403587341309},
#  {'epoch': 100,
#   'learning rate': 1.0000000000000003e-05,
#   'test accuracy': 0.878,
#   'test loss': 0.31851493644714357,
#   'train accuracy': 0.898,
#   'train loss': 0.2783738419850667}]

# %%
train_losses
# Out:
# [1.1068223429361979,
#  1.102372358194987,
#  1.0966899485270183,
#  1.086901284790039,
#  1.0628621805826823,
#  1.0034273880004883,
#  0.928063594563802,
#  0.8709674168904622,
#  0.8154315755208333,
#  0.7646643427530925,
#  0.7040116561889649,
#  0.6470094510396321,
#  0.5981385981241862,
#  0.5643209335327148,
#  0.5375335599263509,
#  0.5136471031188965,
#  0.49767011998494465,
#  0.4806153607686361,
#  0.4632838333129883,
#  0.4518013231913249,
#  0.44161444829305013,
#  0.42997902272542315,
#  0.4208899449666341,
#  0.4079806032816569,
#  0.399787806447347,
#  0.38808841501871744,
#  0.383239576848348,
#  0.37345380160013836,
#  0.3672950304667155,
#  0.3641446590423584,
#  0.3561907379150391,
#  0.34663710009257,
#  0.33910202560424807,
#  0.3387756341934204,
#  0.3301130238850912,
#  0.3277570260365804,
#  0.3246970656077067,
#  0.3183758042653402,
#  0.3180524454752604,
#  0.3152110277811686,
#  0.29617702140808105,
#  0.2936779167175293,
#  0.29362477747599286,
#  0.2926982799530029,
#  0.29162866439819335,
#  0.29102954762776695,
#  0.2921078517913818,
#  0.2885860973993937,
#  0.2894963680267334,
#  0.2875580197016398,
#  0.28945464731852216,
#  0.2877985471089681,
#  0.28892648696899415,
#  0.28900561192830404,
#  0.2867557352701823,
#  0.28569983253479003,
#  0.28657607345581054,
#  0.2847558163960775,
#  0.2878531279246012,
#  0.28482429733276365,
#  0.28201453253428144,
#  0.28304257202148436,
#  0.2824197132110596,
#  0.28306350288391113,
#  0.2810354414621989,
#  0.2826504461924235,
#  0.280522364171346,
#  0.28237382723490395,
#  0.2802091094970703,
#  0.2791328946431478,
#  0.27854351654052734,
#  0.27778611068725584,
#  0.2780486101786296,
#  0.27968655687967936,
#  0.2797854455312093,
#  0.27811107228597004,
#  0.2767999749501546,
#  0.27759184239705403,
#  0.27823872973124186,
#  0.2761971284548442,
#  0.277179371770223,
#  0.27845809364318846,
#  0.2768363343556722,
#  0.2772891263326009,
#  0.2773550506591797,
#  0.2770895837148031,
#  0.2768008209228516,
#  0.27625446275075277,
#  0.2772012500762939,
#  0.2774137274424235,
#  0.2775745422363281,
#  0.27646933619181313,
#  0.2764801951090495,
#  0.27644728202819824,
#  0.27658645502726237,
#  0.2766825401306152,
#  0.2786876881917318,
#  0.2778239870707194,
#  0.2768403587341309,
#  0.2783738419850667]

# %%
len(train_losses)
# Out:
# 100

# %%
len(list(range(1,100)))
# Out:
# 99
